# %%
from src.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from src.Base.Evaluation.Evaluator import EvaluatorHoldout
from src.MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from src.KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from src.KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender

import numpy as np
from operator import itemgetter

import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

data = pd.read_csv("in/data_train.csv")

import scipy.sparse as sps

userList = data['row'].tolist()
itemList = data['col'].tolist()
ratingList = data['data'].tolist()

URM_all = sps.coo_matrix((ratingList, (userList, itemList)))
URM_all = URM_all.tocsr()

from src.Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# Warning: 59 (0.74 %) of 7947 users have no train items
# Warning: 2324 (29.24 %) of 7947 users have no sampled items

# %%
MAP=[]

for topK in [10, 50, 100, 200, 500]:
    for shrink in [0, 10, 50, 100, 200, 500]:
        recommender = ItemKNNCFRecommender(URM_train)
        recommender.fit(topK=topK, shrink=shrink)

        result_dict, _ = evaluator_validation.evaluateRecommender(recommender)

        MAP.append(('topK={}'.format(topK),'shrink={}'.format(shrink),result_dict[10]["MAP"]))
# Out:
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7115.86 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.36 sec. Users per second: 1682
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7403.97 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.35 sec. Users per second: 1688
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7218.11 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.25 sec. Users per second: 1738
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7543.62 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.27 sec. Users per second: 1728
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7234.12 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.29 sec. Users per second: 1718
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7572.43 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.26 sec. Users per second: 1737
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7508.56 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.30 sec. Users per second: 1712
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7597.27 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.38 sec. Users per second: 1675
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7505.87 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.42 sec. Users per second: 1652
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7463.03 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.43 sec. Users per second: 1646
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 6752.64 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.43 sec. Users per second: 1649
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7590.63 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.45 sec. Users per second: 1639
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7483.09 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.42 sec. Users per second: 1655
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 6368.09 column/sec, elapsed time 0.07 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.69 sec. Users per second: 1534
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7201.39 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.60 sec. Users per second: 1573
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7352.07 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.67 sec. Users per second: 1539
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7390.93 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.60 sec. Users per second: 1571
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7491.44 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.57 sec. Users per second: 1585
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7213.87 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.58 sec. Users per second: 1580
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7369.54 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.71 sec. Users per second: 1525
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7344.44 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.72 sec. Users per second: 1519
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7318.60 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.71 sec. Users per second: 1526
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7245.14 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.76 sec. Users per second: 1506
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7377.38 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.71 sec. Users per second: 1525
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7194.15 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.84 sec. Users per second: 1474
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7185.29 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.97 sec. Users per second: 1423
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7115.43 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.94 sec. Users per second: 1436
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7158.79 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.93 sec. Users per second: 1441
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7196.74 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.10 sec. Users per second: 1379
# ItemKNNCFRecommender: URM Detected 69 (0.87 %) cold users.
# ItemKNNCFRecommender: URM Detected 2339 (9.00 %) cold items.
# Similarity column 25975 ( 100 % ), 7128.61 column/sec, elapsed time 0.06 min
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 3.96 sec. Users per second: 1429

# %%
max_tuple = max(MAP, key=itemgetter(2))
print('The best combination for the ICF recommender is ({},{}), with a MAP = {}'.format(max_tuple[0],max_tuple[1], max_tuple[2]))
# Out:
# The best combination for the ICF recommender is (topK=100,shrink=50), with a MAP = 0.052242857053749196

# %%
MAP=[]

for num_factors in np.logspace(1,15,10, base=2).astype(int):
    recommender = PureSVDRecommender(URM_train)
    recommender.fit(num_factors = num_factors)

    result_dict, _ = evaluator_validation.evaluateRecommender(recommender)

    MAP.append(('number of factors={}'.format(num_factors),result_dict[10]["MAP"]))
# Out:
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.66 sec. Users per second: 1213
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.38 sec. Users per second: 1292
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.46 sec. Users per second: 1269
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.60 sec. Users per second: 1230
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 4.95 sec. Users per second: 1141
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 5.94 sec. Users per second: 952
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 8.91 sec. Users per second: 634
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 20.60 sec. Users per second: 275
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5000 ( 88.42% ) in 35.02 sec. Users per second: 143
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 39.89 sec. Users per second: 142
# PureSVDRecommender: URM Detected 69 (0.87 %) cold users.
# PureSVDRecommender: URM Detected 2339 (9.00 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5000 ( 88.42% ) in 36.28 sec. Users per second: 138
# EvaluatorHoldout: Processed 5655 ( 100.00% ) in 41.10 sec. Users per second: 138

# %%
max_tuple = max(MAP, key=itemgetter(1))
print('The best combination for the PureSVD recommender is ({}), with a MAP = {}'.format(max_tuple[0],max_tuple[1]))
# Out:
# The best combination for the PureSVD recommender is (number of factors=1290), with a MAP = 0.03242241064648013

# %%
metadata = pd.read_csv("in/data_ICM_title_abstract.csv")

itemICMList = metadata['row'].tolist()
featureList = metadata['col'].tolist()
weightList = metadata['data'].tolist()

ICM_all = sps.coo_matrix((weightList, (itemICMList, featureList)))
ICM_all = ICM_all.tocsr()

# %%
MAP=[]

for topK in [10, 50, 100, 200, 500]:
    for shrink in [0, 10, 50, 100, 200, 500]:
        recommender = ItemKNNCBFRecommender(URM_train=URM_train, ICM_train=ICM_all)
        recommender.fit(topK=topK, shrink=shrink)

        result_dict, _ = evaluator_validation.evaluateRecommender(recommender)

        MAP.append(('topK={}'.format(topK),'shrink={}'.format(shrink),result_dict[10]["MAP"]))
# Out:
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4912.75 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.14 sec. Users per second: 1792
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4869.25 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.04 sec. Users per second: 1849
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5128.03 column/sec, elapsed time 0.08 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.15 sec. Users per second: 1788
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4960.56 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.04 sec. Users per second: 1851
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5125.14 column/sec, elapsed time 0.08 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.06 sec. Users per second: 1835
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5040.53 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.03 sec. Users per second: 1856
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4368.57 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.18 sec. Users per second: 1770
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4286.22 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.19 sec. Users per second: 1761
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4952.99 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.19 sec. Users per second: 1765
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5138.14 column/sec, elapsed time 0.08 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.11 sec. Users per second: 1810
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4974.83 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.12 sec. Users per second: 1801
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5141.37 column/sec, elapsed time 0.08 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.12 sec. Users per second: 1801
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 5005.52 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.31 sec. Users per second: 1697
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4872.09 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.35 sec. Users per second: 1680
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4906.76 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.28 sec. Users per second: 1714
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4896.92 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.31 sec. Users per second: 1701
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4923.86 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.35 sec. Users per second: 1680
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4993.98 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.33 sec. Users per second: 1687
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4556.48 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.61 sec. Users per second: 1557
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4754.29 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.57 sec. Users per second: 1575
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4775.28 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.57 sec. Users per second: 1575
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4724.87 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.58 sec. Users per second: 1571
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4683.09 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.59 sec. Users per second: 1568
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4735.21 column/sec, elapsed time 0.09 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.58 sec. Users per second: 1572
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4269.40 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.13 sec. Users per second: 1361
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4365.63 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.13 sec. Users per second: 1361
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4327.78 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.12 sec. Users per second: 1365
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4440.33 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.97 sec. Users per second: 1417
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4406.41 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.03 sec. Users per second: 1395
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4270.80 column/sec, elapsed time 0.10 min
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.10 sec. Users per second: 1370

# %%
max_tuple = max(MAP, key=itemgetter(2))
print('The best combination for the CBF recommender is ({},{}), with a MAP = {}'.format(max_tuple[0],max_tuple[1], max_tuple[2]))
# Out:
# The best combination for the CBF recommender is (topK=500,shrink=10), with a MAP = 0.026158480099214582

# %%
MAP=[]

Similarity_1 = ItemKNNCFRecommender(URM_train=URM_train)
Similarity_1.fit(topK=100, shrink=50)
Similarity_1 = Similarity_1.W_sparse
Similarity_2 = ItemKNNCBFRecommender(URM_train=URM_train, ICM_train=ICM_all)
Similarity_2.fit(topK=500, shrink=10)
Similarity_2 = Similarity_2.W_sparse

for topK in [10, 50, 100, 200, 500]:
    for alpha in np.linspace(start=0.0,stop=1.0,num=10):
        recommender = ItemKNNSimilarityHybridRecommender(URM_train=URM_train, Similarity_1=Similarity_1, Similarity_2=Similarity_2)
        recommender.fit(topK=topK, alpha=alpha)

        result_dict, _ = evaluator_validation.evaluateRecommender(recommender)

        MAP.append(('topK={}'.format(topK),'alpha={}'.format(alpha),result_dict[10]["MAP"]))
# Out:
# ItemKNNCFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 7225.40 column/sec, elapsed time 0.06 min
# ItemKNNCBFRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNCBFRecommender: URM Detected 2355 (9.07 %) cold items.
# Similarity column 25975 ( 100 % ), 4197.59 column/sec, elapsed time 0.10 min
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.06 sec. Users per second: 1838
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.24 sec. Users per second: 1736
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.12 sec. Users per second: 1804
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.14 sec. Users per second: 1790
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.10 sec. Users per second: 1813
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.11 sec. Users per second: 1808
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.20 sec. Users per second: 1759
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.13 sec. Users per second: 1794
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.21 sec. Users per second: 1751
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.17 sec. Users per second: 1771
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.28 sec. Users per second: 1717
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.22 sec. Users per second: 1745
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.34 sec. Users per second: 1683
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.41 sec. Users per second: 1648
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.39 sec. Users per second: 1657
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.47 sec. Users per second: 1622
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.35 sec. Users per second: 1677
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.42 sec. Users per second: 1646
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.41 sec. Users per second: 1650
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.31 sec. Users per second: 1700
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.44 sec. Users per second: 1636
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.51 sec. Users per second: 1603
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.59 sec. Users per second: 1564
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.72 sec. Users per second: 1510
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.63 sec. Users per second: 1547
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.66 sec. Users per second: 1535
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.64 sec. Users per second: 1545
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.64 sec. Users per second: 1543
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.64 sec. Users per second: 1546
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.58 sec. Users per second: 1570
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.69 sec. Users per second: 1525
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.21 sec. Users per second: 1334
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.64 sec. Users per second: 1543
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.82 sec. Users per second: 1472
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.80 sec. Users per second: 1479
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.80 sec. Users per second: 1478
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.81 sec. Users per second: 1477
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.84 sec. Users per second: 1465
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.85 sec. Users per second: 1459
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.56 sec. Users per second: 1581
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.22 sec. Users per second: 1334
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.43 sec. Users per second: 1269
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.35 sec. Users per second: 1293
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.31 sec. Users per second: 1304
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.30 sec. Users per second: 1308
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.27 sec. Users per second: 1316
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.27 sec. Users per second: 1316
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.26 sec. Users per second: 1321
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 4.24 sec. Users per second: 1325
# ItemKNNSimilarityHybridRecommender: URM Detected 59 (0.74 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2355 (9.07 %) cold items.
# EvaluatorHoldout: Processed 5623 ( 100.00% ) in 3.44 sec. Users per second: 1635

# %%
max_tuple = max(MAP, key=itemgetter(2))
print('The best combination for the hybrid recommender is ({},{}), with a MAP = {}'.format(max_tuple[0],max_tuple[1], max_tuple[2]))
# Out:
# The best combination for the hybrid recommender is (topK=500,alpha=0.6666666666666666), with a MAP = 0.06221448623349726
