# %%
from src.Base.Evaluation.K_Fold_Evaluator import K_Fold_Evaluator_MAP
from src.SLIM_ElasticNet.SLIMElasticNetRecommender import MultiThreadSLIM_ElasticNet
from src.Utils.ICM_preprocessing import *
from src.Utils.load_ICM import load_ICM
from src.Utils.load_URM import load_URM

URM_all = load_URM("../../in/data_train.csv")
ICM_all = load_ICM("../../in/data_ICM_title_abstract.csv")
from src.Data_manager.split_functions.split_train_validation_random_holdout import \
    split_train_in_two_percentage_global_sample

URMs_train = []
URMs_validation = []

for k in range(3):
    URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage=0.80)
    URMs_train.append(URM_train)
    URMs_validation.append(URM_validation)

evaluator_validation = K_Fold_Evaluator_MAP(URMs_validation, cutoff_list=[10], verbose=False)

ICMs_combined = []
for URM in URMs_train:
    ICMs_combined.append(combine(ICM=ICM_all, URM=URM))

recommenders = []

tuning_params = {
    "alpha": (1e-4, 1e-2),
    "l1_ratio": (0, 1),
    "topK": (10, 500)
}

results = []


def BO_func(
        alpha,
        l1_ratio,
        topK
):
    recommenders = []

    for index in range(len(URMs_train)):
        recommenders.append(
            MultiThreadSLIM_ElasticNet(
                URM_train=ICMs_combined[index].T,
                verbose=False
            )
        )

        recommenders[index].fit(
            alpha=alpha,
            l1_ratio=l1_ratio,
            topK=topK
        )

        recommenders[index].URM_train = URMs_train[index]

    result = evaluator_validation.evaluateRecommender(recommenders)
    results.append(result)
    return sum(result) / len(result)


from bayes_opt import BayesianOptimization

optimizer = BayesianOptimization(
    f=BO_func,
    pbounds=tuning_params,
    verbose=5,
    random_state=5,
)

optimizer.maximize(
    init_points=3,
    n_iter=2
)

import json

with open("logs/FeatureCombined" + recommenders[0].RECOMMENDER_NAME + "_logs.json", 'w') as json_file:
    json.dump(optimizer.max, json_file)
# Out:
# Warning: 63 (0.79 %) of 7947 users have no train items
# Warning: 2247 (28.27 %) of 7947 users have no sampled items
# Warning: 73 (0.92 %) of 7947 users have no train items
# Warning: 2302 (28.97 %) of 7947 users have no sampled items
# Warning: 81 (1.02 %) of 7947 users have no train items
# Warning: 2269 (28.55 %) of 7947 users have no sampled items
# |   iter    |  target   |   alpha   | l1_ratio  |   topK    |
# -------------------------------------------------------------
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\ALEXDRUSO\Anaconda3\envs\RecSysFramework\lib\multiprocessing\pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\ALEXDRUSO\Anaconda3\envs\RecSysFramework\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\ALEXDRUSO\Desktop\RecSysChallenge2020\src\SLIM_ElasticNet\SLIMElasticNetRecommender.py", line 174, in _partial_fit
#     relevant_items_partition = (-model.coef_).argpartition(topK)[0:topK]
# TypeError: Partition index must be integer
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5994c93e6df7> in <module>
#      74 optimizer.maximize(
#      75     init_points=3,
# ---> 76     n_iter=2
#      77 )
#      78
#
# ~\Anaconda3\envs\RecSysFramework\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     172                 iteration += 1
#     173
# --> 174             self.probe(x_probe, lazy=False)
#     175
#     176         self.dispatch(Events.OPTIMIZATION_END)
#
# ~\Anaconda3\envs\RecSysFramework\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     110             self._queue.add(params)
#     111         else:
# --> 112             self._space.probe(params)
#     113             self.dispatch(Events.OPTIMIZATION_STEP)
#     114
#
# ~\Anaconda3\envs\RecSysFramework\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-1-5994c93e6df7> in BO_func(alpha, l1_ratio, topK)
#      53             alpha=alpha,
#      54             l1_ratio=l1_ratio,
# ---> 55             topK=topK
#      56         )
#      57
#
# ~\Desktop\RecSysChallenge2020\src\SLIM_ElasticNet\SLIMElasticNetRecommender.py in fit(self, l1_ratio, alpha, tol, positive_only, topK, workers)
#     210         # avvio il pool passando la funzione (con la parte fissa dell'input)
#     211         # e il rimanente parametro, variabile
# --> 212         res = pool.map(_pfit, np.arange(n_items))
#     213
#     214         # res contains a vector of (values, rows, cols) tuples
#
# ~\Anaconda3\envs\RecSysFramework\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~\Anaconda3\envs\RecSysFramework\lib\multiprocessing\pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# TypeError: Partition index must be integer
